# %% [markdown]
# <a href="https://colab.research.google.com/github/meryalvesalves6-lgtm/Engenharia_de_Prompt_Aplicacao_AI/blob/main/Aula07_Programac%C3%A3oAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
